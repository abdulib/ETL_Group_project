# %% [markdown]
# Import the election data.

# %%
import csv
import pandas as pd

# %%
electionfile = "../data/source/1976-2018-senate.csv"
election_df = pd.read_csv(electionfile)
election_df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  Arizona       AZ           4         86        61  US Senate
# 1  1976  Arizona       AZ           4         86        61  US Senate
# 2  1976  Arizona       AZ           4         86        61  US Senate
# 3  1976  Arizona       AZ           4         86        61  US Senate
# 4  1976  Arizona       AZ           4         86        61  US Senate
#
#     district stage  special            candidate        party  writein   mode  \
# 0  statewide   gen    False          Sam Steiger   republican    False  total
# 1  statewide   gen    False  Wm. Mathews Feighan  independent    False  total
# 2  statewide   gen    False     Dennis DeConcini     democrat    False  total
# 3  statewide   gen    False        Allan Norwitz  libertarian    False  total
# 4  statewide   gen    False            Bob Field  independent    False  total
#
#    candidatevotes  totalvotes  unofficial     version
# ...

# %% [markdown]
# Slice and dice the data to retain only  what we really need.,

# %%
xyz = ["year","state","state_po","candidate","party","candidatevotes","totalvotes","stage"]
election_df = election_df[xyz]
election_df.head()
# Out:
#    year    state state_po            candidate        party  candidatevotes  \
# 0  1976  Arizona       AZ          Sam Steiger   republican          321236
# 1  1976  Arizona       AZ  Wm. Mathews Feighan  independent            1565
# 2  1976  Arizona       AZ     Dennis DeConcini     democrat          400334
# 3  1976  Arizona       AZ        Allan Norwitz  libertarian            7310
# 4  1976  Arizona       AZ            Bob Field  independent           10765
#
#    totalvotes stage
# 0      741210   gen
# 1      741210   gen
# 2      741210   gen
# 3      741210   gen
# 4      741210   gen

# %%
election_df = election_df.loc[election_df["year"] > 2005, :]
election_df = election_df.loc[election_df["stage"] == "gen", :]

# %%
election_df.head()
# Out:
#       year       state state_po        candidate              party  \
# 2125  2006     Arizona       AZ     Jim Pederson           democrat
# 2126  2006     Arizona       AZ              NaN                NaN
# 2127  2006     Arizona       AZ          Jon Kyl         republican
# 2128  2006     Arizona       AZ     Richard Mack        libertarian
# 2129  2006  California       CA  Marsha Feinland  peace and freedom
#
#       candidatevotes  totalvotes stage
# 2125          664141     1526782   gen
# 2126              12     1526782   gen
# 2127          814398     1526782   gen
# 2128           48231     1526782   gen
# 2129          117764     8541476   gen

# %% [markdown]
# Identify the election winners

# %%
election_df = election_df.sort_values(["year","state","candidatevotes"], ascending=[True, True, False])
election_df.head()
# Out:
#       year       state state_po         candidate        party  \
# 2127  2006     Arizona       AZ           Jon Kyl   republican
# 2125  2006     Arizona       AZ      Jim Pederson     democrat
# 2128  2006     Arizona       AZ      Richard Mack  libertarian
# 2126  2006     Arizona       AZ               NaN          NaN
# 2131  2006  California       CA  Dianne Feinstein     democrat
#
#       candidatevotes  totalvotes stage
# 2127          814398     1526782   gen
# 2125          664141     1526782   gen
# 2128           48231     1526782   gen
# 2126              12     1526782   gen
# 2131         5076289     8541476   gen
