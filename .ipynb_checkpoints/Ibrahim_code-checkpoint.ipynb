# %%
import pandas as pd
from splinter import Browser

# %%
from bs4 import BeautifulSoup
import requests

# %%
credit_card_url = 'https://www.valuepenguin.com/average-credit-card-debt'

# %%
#cc_table = pd.read_html(credit_card_url)
#cc_table

# %%
response = requests.get(credit_card_url,  headers = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'})

# %%
soup = BeautifulSoup(response.text, 'html.parser')
#soup

# %%
#cc_table = pd.read_html(soup)
#cc_table

# %%
tables = soup.find_all('div', class_='table-inner')
#tables

# %%
congress_url = 'https://www.congress.gov/search?searchResultViewType=expanded&q={%22congress%22:[%22115%22],%22source%22:%22legislation%22,%22search%22:%22student+debt+loan+education%22,%22chamber%22:%22Senate%22}&pageSize=250'

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(congress_url)

# %%
# response = requests.get(congress_url)
soup = BeautifulSoup(browser.html, 'html.parser')

# %%
soup
# Out:
# <html class=" js canvas canvastext geolocation crosswindowmessaging websqldatabase indexeddb hashchange historymanagement draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions video audio localstorage sessionstorage webworkers applicationcache svg smil svgclippaths fontface" lang="en"><head>
# <title>Legislative Search Results | Congress.gov | Library of Congress</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="https://www.congress.gov/search" name="canonical"/>
# <meta content="https://www.congress.gov/search" name="dc.identifier"/>
# <meta content="eng" name="dc.language"/>
# <meta content="Text is government work" name="dc.rights"/>
# <meta content="Legislative Data" name="dc.subject"/>
# <meta content="Congress" name="dc.subject"/>
# <meta content="Legislative Search Results" name="dc.title"/>
# <meta content="legislation" name="dc.type"/>
# <meta content="webpage" name="dc.type"/>
# <meta content="Search Results from U.S. Congress legislation, Congressional Record debates, Members of Congress, legislative process educational resources presented by the Library of Congress" name="description"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="Search Results from U.S. Congress legislation, Congressional Record debates, Members of Congress, legislative process educational resources presented by the Library of Congress" property="og:description"/>
# <meta content="https://www.congress.gov/img/FB_opengraph1200by630.jpg" property="og:image"/>
# <meta content="Legislative Search Results" property="og:title"/>
# <meta content="https://www.congress.gov/search" property="og:url"/>
# <link href="/apple-touch-icon-precomposed.png" rel="image_src"/>
# <link href="https://www.congress.gov" rel="dc.relation.isPartOf" title="Congress.gov"/>
# <link href="https://www.congress.gov" rel="dc.relation.isPartOf" title="Legislation"/>
# <link href="/css/cache/71394cade5ce5d52ae56863f2f910e86.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var CDN_URL = 'https://cdn.loc.gov',
#             LAB_URL = 'https://cdn.loc.gov/js/LAB-2.0.3.min.js',
#             MEDIA_URL = 'https://media.loc.gov';
#     </script>
# <script src="/js/cache/96c03eea87ac4b9838b96701ffc48c4d.js" type="text/javascript"></script>
# <script src="https://assets.adobedtm.com/dac62e20b491e735c6b56e64c39134d8ee93f9cf/satelliteLib-2b0167cca1e45644bd67a3b7c1325a52d6d3e835.js" type="text/javascript"></script>
# <script src="https://assets.adobedtm.com/dac62e20b491e735c6b56e64c39134d8ee93f9cf/s-code-contents-677f54156b27153b66eb15fab25b223d622e88dc.js"></script></head>
# <body>
# <p aria-level="1" class="alert_homepage" role="heading" style="display:none;" tabindex="0"></p>
# <noscript>
# <div aria-level="1" class="js-message" role="heading" tabindex="0">
# <span class="hide_fromsighted">Alert: </span>For a better experience on congress.gov, please enable JavaScript in
#             your browser.
#         </div>
# </noscript>
# <div class="container full-width" id="container">
# <div class="container_shadow">
# <header id="top-level-search" role="banner">
# <div class="header-wrapper">
# <div class="header-menu">
# <button aria-controls="nav-links-clone-wrapper" aria-expanded="false" class="nav-links-toggle" id="label-nav-global"><span class="hide_fromsighted">Navigation</span><i class="fa fa-bars"></i></button>
# <nav aria-labelledby="label-nav-global" class="nav-links-clone-wrapper" id="nav-links-clone-wrapper" style="display: none;"><ul class="nav-links-clone nav-links-clone-main">
# <li><a href="/legislation?q=%7B%22congress%22%3A116%7D">Legislation</a></li>
# <li><a href="/congressional-record">Congressional Record</a></li>
# <li><a href="/committees">Committees</a></li>
# <li><a href="/members?q=%7B%22congress%22%3A116%7D">Members</a></li>
# <li class="tertiary nav-links-clone"><a href="/help/legislative-glossary">Glossary</a></li><li class="tertiary nav-links-clone"><a href="/resources/" target="_blank">Resources</a></li><li class="tertiary nav-links-clone"><a href="/help">Help</a></li><li class="tertiary nav-links-clone"><a href="/contact-us">Contact</a></li></ul></nav>
# </div>
# <div class="header-logo">
# <a href="https://www.congress.gov"><img alt="Congress.gov" height="28" src="/img/svg/congress-gov-logo.svg" width="302"/></a>
# </div>
# <div class="header-search-links">
# <ul class="nav-links nav-links-search">
# <li class="advanced-search-link "><a href="/advanced-search/legislation">Advanced Searches</a></li>
# <li class="browse-link "><a href="/browse">Browse</a></li>
# </ul>
# </div>
# <div class="header-portal-links">
# <ul class="nav-links nav-links-main">
# <li><a href="/legislation?q=%7B%22congress%22%3A116%7D">Legislation</a></li>
# <li><a href="/congressional-record">Congressional Record</a></li>
# <li><a href="/committees">Committees</a></li>
# <li><a href="/members?q=%7B%22congress%22%3A116%7D">Members</a></li>
# </ul>
# </div>
# <div class="header-search-tools">
# <ul class="nav-links nav-links-tertiary">
# <li><a href="/help/search-tools-overview">Search Tools</a></li>
# <li class="tertiary-more">
# <a aria-controls="more-tertiary-links" aria-expanded="false" class="tertiary-more-toggle" href="#" id="tertiary-more-toggle" role="button">Support <i class="fa fa-caret-down"></i></a>
# <ul aria-labelledby="tertiary-more-toggle" class="more-tertiary-links" id="more-tertiary-links" style="display: none;">
# <li class="tertiary"><a href="/help/legislative-glossary">Glossary</a></li>
# <li class="tertiary"><a href="/resources/" target="_blank">Resources</a></li>
# <li class="tertiary"><a href="/help">Help</a></li>
# <li class="tertiary"><a href="/contact-us">Contact</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="nav-account"> <div class="h_account"><a class="sign-in-link" href="#">Sign In <i class="fa fa-caret-down"></i></a></div>
# <script>
#         $(document).ready(function() {
#             $('.h_account').congress_AccountLink({
#                 accountLandingUrl:  '/account',
#                 accountRegisterUrl: '/account/register',
#                 accountSignInUrl:   '/account/signin',
#                 alertsUrl:          '/alerts',
#                 checkForUserUrl:    '/account/check-for-user',
#                 debugging:          false,
#                 logoutUrl:          '/account/logout',
#                 passwordResetUrl:   '/account/password-reset-request',
#                 savedSearchesUrl:   '/saved-searches'
#             });
#         });
#         </script>
# </div>
# </div>
# <div class="search-main" id="search_main">
# <div id="search-panel-container">
# <div aria-labelledby="basic-search-button" class="basic-search-panel" id="basic-search-panel">
# <div class="search-within-results-inputs" id="search-within-results-inputs" style="display:none;">
# <input name="searchResultViewType" type="hidden" value="expanded"/><input name="q" type="hidden" value='{"congress":["115"],"source":"legislation","search":"student debt loan education","chamber":"Senate"}'/><input name="pageSize" type="hidden" value="250"/> </div>
# <form action="/search" class="search-main-form" method="get" role="search" target="_top">
# <div class="search-wrapper" id="search-wrapper">
# <div class="search-formats">
# <select aria-label="Search" id="search-format" name="search-source">
# <option selected="selected" value="current-legislation">Current Legislation</option><option value="legislation">All Legislation</option><option value="all-sources">All Sources</option><option disabled="disabled" value="--">--</option><option value="comreports">Committee Reports</option><option value="congrecord">Congressional Record</option><option value="members">Members</option><option value="nominations">Nominations</option><option value="house-communications">House Communications</option><option value="senate-communications">Senate Communications</option><option value="treaties">Treaty Documents</option> </select>
# </div>
# <div class="search-input">
# <input class="locsuggest" id="search" name="q" placeholder='Examples: hr5, sres9, "health care"' type="text" value=""/>
# <div class="search-within-results-container" id="search-within-results-container" style="display: block;">
# <label>Search Within <input id="search-within-results" name="search-within" type="checkbox"/></label>
# </div>
# </div>
# <div class="search-button">
# <button class="search-submit" id="search-submit" type="button"><span class="hide_fromsighted">GO</span><i class="fa fa-search"></i></button>
# </div>
# </div>
# </form>
# </div>
# <div aria-labelledby="quick-search-button" class="quick-search-panel" id="quick-search-panel" style="display: block; position: absolute; top: -10000px; visibility: hidden;">
# <div class="quick-search-tabui" id="quick-search-tabui">
# <nav class="quick-search-tabui-tabs" role="navigation">
# <ul>
# <li><a aria-controls="legislation" aria-expanded="true" class="active" href="#legislation" id="legislation-tab">Legislation</a></li>
# <li><a aria-controls="legislation-text" aria-expanded="false" href="#legislation-text" id="legislation-text-tab">Legislation Text</a></li>
# <li><a aria-controls="committee-reports" aria-expanded="false" href="#committee-reports" id="committee-reports-tab">Committee Reports</a></li>
# <li><a aria-controls="congressional-record" aria-expanded="false" href="#congressional-record" id="congressional-record-tab">Congressional Record</a></li>
# <li><a aria-controls="nominations" aria-expanded="false" href="#nominations" id="nominations-tab">Nominations</a></li>
# <li><a aria-controls="house-communications" aria-expanded="false" href="#house-communications" id="house-communications-tab">House Communications</a></li>
# <li><a aria-controls="senate-communications" aria-expanded="false" href="#senate-communications" id="senate-communications-tab">Senate Communications</a></li>
# <li><a aria-controls="treaty-documents" aria-expanded="false" href="#treaty-documents" id="treaty-documents-tab">Treaty Documents</a></li>
# </ul>
# </nav>
# <div class="quick-search-tabui-tab-panels">
# <div aria-labelledby="legislation-tab" class="quick-search-tabui-tab-panel active" id="legislation">
# <form action="/quick-search/legislation" aria-labelledby="quick-search" class="quick-search" id="quick=search-legislation">
# <div class="quick-search-form-row-words-and-phrases">
# <div class="quick-search-form-row quick-search-form-row-buttons quick-search-form-row-buttons-top">
# <button class="button tertiary2 reset" type="button">Reset</button>
# </div>
# <label class="quick-search-label quick-search-words-and-phrases-label" for="legislation-wordsPhrases">Words &amp; Phrases</label>
# <textarea aria-label="Words and Phrases" class="expand80-2000 words-and-phrases" id="legislation-wordsPhrases" name="wordsPhrases" placeholder='Examples: "Trade Relations", "Export Control"' row="1"></textarea>
# </div>
# <div class="quick-search-form-row quick-search-form-row-after-words-and-phrases">
# <div class="quick-search-group">
# <div>
# <label class="quick-search-label-checkradio" for="legislation-include"><input id="legislation-include" name="include" type="checkbox"/> Include bill text in this search</label>
# </div>
# <div>
# <label class="quick-search-label-checkradio" for="legislation-wordVariants"><input checked="checked" id="legislation-wordVariants" name="wordVariants" type="checkbox" value="on"/> Word Variants</label>
# <label class="quick-search-label-checkradio" for="legislation-caseSensitive"><input id="legislation-caseSensitive" name="caseSensitive" type="checkbox" value="on"/> Case Sensitive</label>
# </div>
# <div>
# <span class="quick-search-group-title">Search Only:</span>
# <label class="quick-search-label-checkradio" for="legislation-titles"><input id="legislation-titles" name="titles" type="checkbox" value="on"/> Titles</label>
# <label class="quick-search-label-checkradio" for="legislation-summaries"><input id="legislation-summaries" name="summaries" type="checkbox" value="on"/> Summaries</label>
# <label class="quick-search-label-checkradio" for="legislation-actions"><input id="legislation-actions" name="actions" type="checkbox" value="on"/> Actions</label>
# </div>
# </div>
# </div>
# <div class="quick-search-column-wrapper">
# <div class="quick-search-two-column">
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="legislation-congresses">Congress</label>
# <select id="legislation-congresses" multiple="" name="congresses[]" size="5">
# <option value="all">All Congresses 93-116 (1973-2020)</option><option selected="selected" value="116">116 (2019-2020)</option><option selected="selected" value="115">115 (2017-2018)</option><option value="114">114 (2015-2016)</option><option value="113">113 (2013-2014)</option><option value="112">112 (2011-2012)</option><option value="111">111 (2009-2010)</option><option value="110">110 (2007-2008)</option><option value="109">109 (2005-2006)</option><option value="108">108 (2003-2004)</option><option value="107">107 (2001-2002)</option><option value="106">106 (1999-2000)</option><option value="105">105 (1997-1998)</option><option value="104">104 (1995-1996)</option><option value="103">103 (1993-1994)</option><option value="102">102 (1991-1992)</option><option value="101">101 (1989-1990)</option><option value="100">100 (1987-1988)</option><option value="99">99 (1985-1986)</option><option value="98">98 (1983-1984)</option><option value="97">97 (1981-1982)</option><option value="96">96 (1979-1980)</option><option value="95">95 (1977-1978)</option><option value="94">94 (1975-1976)</option><option value="93">93 (1973-1974)</option> </select>
# </div>
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="legislation-legislationNumbers">Legislation and Law Numbers</label>
# <input id="legislation-legislationNumbers" name="legislationNumbers" placeholder="Examples: hr5, h.r.5, sjres 8, sa2, pl114-4" type="text" value=""/>
# </div>
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="legislation-legislativeActions">Legislative Actions</label>
# <select class="need-margin-bottom" id="legislation-legislativeActions" name="legislativeAction">
# <option value="">Any Legislative Action</option>
# <option value="100">Introduced (Bills and Resolutions)</option><option value="101">Committee or floor actions</option><option value="102">Reported to House/Committee discharged</option><option value="103">Reported to Senate/Committee discharged</option><option value="104">House floor actions</option><option value="105">Senate floor actions</option><option value="106">Failed of passage/not agreed to in House</option><option value="107">Failed of passage/not agreed to in Senate</option><option value="108">Passed/agreed to in House</option><option value="109">Passed/agreed to in Senate</option><option value="110">Passed/agreed to in House and Senate</option><option value="111">Resolving differences including conferences</option><option value="113">Conference report agreed to in House and Senate</option><option value="114">Vetoes and pocket vetoes</option><option value="115">Laws</option> </select>
# </div>
# </div>
# <div class="quick-search-two-column">
# <div class="quick-search-form-row">
# <fieldset class="quick-search-fieldset">
# <legend class="quick-search-legend">Sponsors/Cosponsors</legend>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="legislation-sponsor"><input checked="checked" id="legislation-sponsor" name="sponsor" type="checkbox"/> Sponsor</label></div>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="legislation-co-sponsor"><input id="legislation-co-sponsor" name="cosponsor" type="checkbox"/> Cosponsor</label></div>
# <select class="need-margin-bottom" id="legislation-representatives" name="representative">
# <option value="">Any Representative</option>
# <option value="A000374">Abraham, Ralph Lee [R-LA] (114th-116th)</option><option value="A000370">Adams, Alma S. [D-NC] (113th-116th)</option><option value="A000055">Aderholt, Robert B. [R-AL] (105th-116th)</option><option value="A000371">Aguilar, Pete [D-CA] (114th-116th)</option><option value="A000372">Allen, Rick W. [R-GA] (114th-116th)</option><option value="A000376">Allred, Colin Z. [D-TX] (116th)</option><option value="A000367">Amash, Justin [R-MI] (112th-116th)</option><option value="A000369">Amodei, Mark E. [R-NV] (112th-116th)</option><option value="A000377">Armstrong, Kelly [R-ND] (116th)</option><option value="A000375">Arrington, Jodey C. [R-TX] (115th-116th)</option><option value="A000378">Axne, Cynthia [D-IA] (116th)</option><option value="B001291">Babin, Brian [R-TX] (114th-116th)</option><option value="B001298">Bacon, Don [R-NE] (115th-116th)</option><option value="B001307">Baird, James R. [R-IN] (116th)</option><option value="B001306">Balderson, Troy [R-OH] (115th-116th)</option><option value="B001299">Banks, Jim [R-IN] (115th-116th)</option><option value="B001269">Barletta, Lou [R-PA] (112th-115th)</option><option value="B001282">Barr, Andy [R-KY] (113th-116th)</option><option value="B001300">Barragan, Nanette Diaz [D-CA] (115th-116th)</option><option value="B000213">Barton, Joe [R-TX] (99th-115th)</option><option value="B001270">Bass, Karen [D-CA] (112th-116th)</option><option value="B001281">Beatty, Joyce [D-OH] (113th-116th)</option><option value="B000287">Becerra, Xavier [D-CA] (103rd-115th)</option><option value="B001287">Bera, Ami [D-CA] (113th-116th)</option><option value="B001301">Bergman, Jack [R-MI] (115th-116th)</option><option value="B001292">Beyer, Donald S., Jr. [D-VA] (114th-116th)</option><option value="B001302">Biggs, Andy [R-AZ] (115th-116th)</option><option value="B001257">Bilirakis, Gus M. [R-FL] (110th-116th)</option><option value="B001293">Bishop, Mike [R-MI] (114th-115th)</option><option value="B001250">Bishop, Rob [R-UT] (108th-116th)</option><option value="B000490">Bishop, Sanford D., Jr. [D-GA] (103rd-116th)</option><option value="B001273">Black, Diane [R-TN] (112th-115th)</option><option value="B001243">Blackburn, Marsha [R-TN] (108th-115th)</option><option value="B001294">Blum, Rod [R-IA] (114th-115th)</option><option value="B000574">Blumenauer, Earl [D-OR] (104th-116th)</option><option value="B001303">Blunt Rochester, Lisa [D-DE] (115th-116th)</option><option value="B001278">Bonamici, Suzanne [D-OR] (112th-116th)</option><option value="B001245">Bordallo, Madeleine Z. [D-GU] (108th-115th)</option><option value="B001295">Bost, Mike [R-IL] (114th-116th)</option><option value="B001296">Boyle, Brendan F. [D-PA] (114th-116th)</option><option value="B000755">Brady, Kevin [R-TX] (105th-116th)</option><option value="B001227">Brady, Robert A. [D-PA] (105th-115th)</option><option value="B001290">Brat, Dave [R-VA] (113th-115th)</option><option value="B001283">Bridenstine, Jim [R-OK] (113th-115th)</option><option value="B001308">Brindisi, Anthony [D-NY] (116th)</option><option value="B001274">Brooks, Mo [R-AL] (112th-116th)</option><option value="B001284">Brooks, Susan W. [R-IN] (113th-116th)</option><option value="B001304">Brown, Anthony G. [D-MD] (115th-116th)</option><option value="B001285">Brownley, Julia [D-CA] (113th-116th)</option><option value="B001260">Buchanan, Vern [R-FL] (110th-116th)</option><option value="B001297">Buck, Ken [R-CO] (114th-116th)</option><option value="B001275">Bucshon, Larry [R-IN] (112th-116th)</option><option value="B001305">Budd, Ted [R-NC] (115th-116th)</option><option value="B001309">Burchett, Tim [R-TN] (116th)</option><option value="B001248">Burgess, Michael C. [R-TX] (108th-116th)</option><option value="B001286">Bustos, Cheri [D-IL] (113th-116th)</option><option value="B001251">Butterfield, G. K. [D-NC] (108th-116th)</option><option value="B001289">Byrne, Bradley [R-AL] (113th-116th)</option><option value="C000059">Calvert, Ken [R-CA] (103rd-116th)</option><o ...
# <select id="legislation-senators" name="senator">
# <option value="">Any Senator</option>
# <option value="A000360">Alexander, Lamar [R-TN] (108th-116th)</option><option value="B001230">Baldwin, Tammy [D-WI] (113th-116th)</option><option value="B001261">Barrasso, John [R-WY] (110th-116th)</option><option value="B001267">Bennet, Michael F. [D-CO] (111th-116th)</option><option value="B001243">Blackburn, Marsha [R-TN] (116th)</option><option value="B001277">Blumenthal, Richard [D-CT] (112th-116th)</option><option value="B000575">Blunt, Roy [R-MO] (112th-116th)</option><option value="B001288">Booker, Cory A. [D-NJ] (113th-116th)</option><option value="B001236">Boozman, John [R-AR] (112th-116th)</option><option value="B001310">Braun, Mike  [R-IN] (116th)</option><option value="B000944">Brown, Sherrod [D-OH] (110th-116th)</option><option value="B001135">Burr, Richard [R-NC] (109th-116th)</option><option value="C000127">Cantwell, Maria [D-WA] (107th-116th)</option><option value="C001047">Capito, Shelley Moore [R-WV] (114th-116th)</option><option value="C000141">Cardin, Benjamin L. [D-MD] (110th-116th)</option><option value="C000174">Carper, Thomas R. [D-DE] (107th-116th)</option><option value="C001070">Casey, Robert P., Jr. [D-PA] (110th-116th)</option><option value="C001075">Cassidy, Bill [R-LA] (114th-116th)</option><option value="C000567">Cochran, Thad [R-MS] (96th-115th)</option><option value="C001035">Collins, Susan M. [R-ME] (105th-116th)</option><option value="C001088">Coons, Christopher A. [D-DE] (111th-116th)</option><option value="C001071">Corker, Bob [R-TN] (110th-115th)</option><option value="C001056">Cornyn, John [R-TX] (107th-116th)</option><option value="C001113">Cortez Masto, Catherine  [D-NV] (115th-116th)</option><option value="C001095">Cotton, Tom [R-AR] (114th-116th)</option><option value="C001096">Cramer, Kevin [R-ND] (116th)</option><option value="C000880">Crapo, Mike [R-ID] (106th-116th)</option><option value="C001098">Cruz, Ted [R-TX] (113th-116th)</option><option value="D000618">Daines, Steve [R-MT] (114th-116th)</option><option value="D000607">Donnelly, Joe [D-IN] (113th-115th)</option><option value="D000622">Duckworth, Tammy [D-IL] (115th-116th)</option><option value="D000563">Durbin, Richard J. [D-IL] (105th-116th)</option><option value="E000285">Enzi, Michael B. [R-WY] (105th-116th)</option><option value="E000295">Ernst, Joni  [R-IA] (114th-116th)</option><option value="F000062">Feinstein, Dianne [D-CA] (102nd-116th)</option><option value="F000463">Fischer, Deb [R-NE] (113th-116th)</option><option value="F000444">Flake, Jeff [R-AZ] (113th-115th)</option><option value="F000457">Franken, Al [D-MN] (111th-115th)</option><option value="G000562">Gardner, Cory [R-CO] (114th-116th)</option><option value="G000555">Gillibrand, Kirsten E. [D-NY] (111th-116th)</option><option value="G000359">Graham, Lindsey [R-SC] (108th-116th)</option><option value="G000386">Grassley, Chuck [R-IA] (97th-116th)</option><option value="H001075">Harris, Kamala D. [D-CA] (115th-116th)</option><option value="H001076">Hassan, Margaret Wood [D-NH] (115th-116th)</option><option value="H000338">Hatch, Orrin G. [R-UT] (95th-115th)</option><option value="H001089">Hawley, Josh  [R-MO] (116th)</option><option value="H001046">Heinrich, Martin [D-NM] (113th-116th)</option><option value="H001069">Heitkamp, Heidi [D-ND] (113th-115th)</option><option value="H001041">Heller, Dean [R-NV] (112th-115th)</option><option value="H001042">Hirono, Mazie K. [D-HI] (113th-116th)</option><option value="H001061">Hoeven, John [R-ND] (112th-116th)</option><option value="H001079">Hyde-Smith, Cindy [R-MS] (115th-116th)</option><option value="I000024">Inhofe, James M. [R-OK] (103rd-116th)</option><option value="I000055">Isakson, Johnny [R-GA] (109th-116th)</option><option value="J000293">Johnson, Ron [R-WI] (112th-116th)</option><option value="J000300">Jones, Doug  [D-AL] (115th-116th)</option><option value="K000384">Kaine, Tim [D-VA] (113th-116th)</option><option value="K000393">Kennedy, John [R-LA] (115th-116th)</option><option value="K000383">King, Angus  ...
# </fieldset>
# </div>
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="legislation-houseCommittees">Committees</label>
# <div id="legislation-houseCommittees"><span class="multiselect-native-select"><select class="need-margin-bottom bootstrap-multiselect" id="legislation-houseCommittees-multiselect" multiple=""><optgroup label="Agriculture (93rd-116th)" value="hsag00"><option label="Agriculture (93rd-116th)" value="5473"></option></optgroup><optgroup label="Appropriations (93rd-116th)" value="hsap00"><option label="Appropriations (93rd-116th)" value="5520"></option></optgroup><optgroup label="Armed Services (93rd-103rd, 106th-116th)" value="hsas00"><option label="Armed Services (93rd-103rd, 106th-116th)" value="5568"></option></optgroup><optgroup label="Budget (93rd-116th)" value="hsbu00"><option label="Budget (93rd-116th)" value="5672"></option></optgroup><optgroup label="Education and Labor (All Names)" value="hsed00"><option label="Education and Labor (116th)" value="6961"></option><option label="Education and the Workforce (112th-115th)" value="5683"></option></optgroup><optgroup label="Energy and Commerce (97th-103rd, 107th-116th)" value="hsif00"><option label="Energy and Commerce (97th-103rd, 107th-116th)" value="5886"></option></optgroup><optgroup label="Ethics (112th-116th)" value="hsso00"><option label="Ethics (112th-116th)" value="6147"></option></optgroup><optgroup label="Financial Services (107th-116th)" value="hsba00"><option label="Financial Services (107th-116th)" value="5627"></option></optgroup><optgroup label="Foreign Affairs (93rd, 95th-103rd, 110th-116th)" value="hsfa00"><option label="Foreign Affairs (93rd, 95th-103rd, 110th-116th)" value="5726"></option></optgroup><optgroup label="Homeland Security (109th-116th)" value="hshm00"><option label="Homeland Security (109th-116th)" value="5860"></option></optgroup><optgroup label="House Administration (93rd-103rd, 106th-116th)" value="hsha00"><option label="House Administration (93rd-103rd, 106th-116th)" value="5846"></option></optgroup><optgroup label="Intelligence (Permanent Select) (95th-116th)" value="hlig00"><option label="Intelligence (Permanent Select) (95th-116th)" value="5435"></option></optgroup><optgroup label="Judiciary (93rd-116th)" value="hsju00"><option label="Judiciary (93rd-116th)" value="5994"></option></optgroup><optgroup label="Natural Resources (103rd, 110th-116th)" value="hsii00"><option label="Natural Resources (103rd, 110th-116th)" value="5938"></option></optgroup><optgroup label="Oversight and Reform (All Names)" value="hsgo00"><option label="Oversight and Reform (116th)" value="6941"></option><option label="Oversight and Government Reform (110th-115th)" value="5777"></option></optgroup><optgroup label="Rules (93rd-116th)" value="hsru00"><option label="Rules (93rd-116th)" value="6085"></option></optgroup><optgroup label="Science, Space, and Technology (112th-116th)" value="hssy00"><option label="Science, Space, and Technology (112th-116th)" value="6152"></option></optgroup><optgroup label="Small Business (93rd, 94th-116th)" value="hssm00"><option label="Small Business (93rd, 94th-116th)" value="6093"></option></optgroup><optgroup label="Transportation and Infrastructure (104th-116th)" value="hspw00"><option label="Transportation and Infrastructure (104th-116th)" value="6053"></option></optgroup><optgroup label="Veterans' Affairs (93rd-116th)" value="hsvr00"><option label="Veterans' Affairs (93rd-116th)" value="6212"></option></optgroup><optgroup label="Ways and Means (93rd-116th)" value="hswm00"><option label="Ways and Means (93rd-116th)" value="6225"></option></optgroup></select><div class="btn-group"><button class="multiselect dropdown-toggle btn btn-default" data-toggle="dropdown" title="Any House Committees" type="button"><span class="multiselect-selected-text">Any House Committees</span> <b class="caret"></b></button><ul class="multiselect-container dropdown-menu" style="max-height: 426px; overflow: hidden auto;"><li class="multiselect-item multiselect-group"><a href="javascript:void(0);"><label><input type="checkbox" value="hsag00"/><b style="font-we ...
# </div>
# </div>
# <div class="quick-search-form-row quick-search-form-row-buttons">
# <input name="searchResultViewType" type="hidden" value="expanded"/>
# <button class="button primary2 submit" type="button">Search</button>
# <button class="button tertiary2 reset" type="button">Reset</button>
# </div>
# <div class="quick-search-form-row quick-search-form-row-intro">
# <a href="/legislation/about" target="_blank">About Legislation</a> | <a href="/browse#browse_actions">Browse Legislation by Actions</a> </div>
# </form>
# <script>
# $('#legislation form.quick-search').congress_QuickSearchLegislation({
#     defaults: {"congresses":[116,115],"legislationNumbers":"","include":"","wordsPhrases":"","wordVariants":"on","caseSensitive":"","titles":"","summaries":"","actions":"","sponsor":"on","cosponsor":"","representative":"","senator":"","houseCommittee":"","senateCommittee":"","legislativeAction":""},
#     displayMessages: {"QUICK_SEARCH_MULTISELECT_MANY_SELECTIONS":"Click here to see your selections."},
#     getOptionsUrl: '/quick-search/get-options',
#     resetFormUrl: '/quick-search/reset-form-selections',
#     houseMultiselectData: [{"label":"Agriculture (93rd-116th)","value":"hsag00","children":[{"label":"Agriculture (93rd-116th)","value":5473}]},{"label":"Appropriations (93rd-116th)","value":"hsap00","children":[{"label":"Appropriations (93rd-116th)","value":5520}]},{"label":"Armed Services (93rd-103rd, 106th-116th)","value":"hsas00","children":[{"label":"Armed Services (93rd-103rd, 106th-116th)","value":5568}]},{"label":"Budget (93rd-116th)","value":"hsbu00","children":[{"label":"Budget (93rd-116th)","value":5672}]},{"label":"Education and Labor (All Names)","value":"hsed00","children":[{"label":"Education and Labor (116th)","value":6961},{"label":"Education and the Workforce (112th-115th)","value":5683}]},{"label":"Energy and Commerce (97th-103rd, 107th-116th)","value":"hsif00","children":[{"label":"Energy and Commerce (97th-103rd, 107th-116th)","value":5886}]},{"label":"Ethics (112th-116th)","value":"hsso00","children":[{"label":"Ethics (112th-116th)","value":6147}]},{"label":"Financial Services (107th-116th)","value":"hsba00","children":[{"label":"Financial Services (107th-116th)","value":5627}]},{"label":"Foreign Affairs (93rd, 95th-103rd, 110th-116th)","value":"hsfa00","children":[{"label":"Foreign Affairs (93rd, 95th-103rd, 110th-116th)","value":5726}]},{"label":"Homeland Security (109th-116th)","value":"hshm00","children":[{"label":"Homeland Security (109th-116th)","value":5860}]},{"label":"House Administration (93rd-103rd, 106th-116th)","value":"hsha00","children":[{"label":"House Administration (93rd-103rd, 106th-116th)","value":5846}]},{"label":"Intelligence (Permanent Select) (95th-116th)","value":"hlig00","children":[{"label":"Intelligence (Permanent Select) (95th-116th)","value":5435}]},{"label":"Judiciary (93rd-116th)","value":"hsju00","children":[{"label":"Judiciary (93rd-116th)","value":5994}]},{"label":"Natural Resources (103rd, 110th-116th)","value":"hsii00","children":[{"label":"Natural Resources (103rd, 110th-116th)","value":5938}]},{"label":"Oversight and Reform (All Names)","value":"hsgo00","children":[{"label":"Oversight and Reform (116th)","value":6941},{"label":"Oversight and Government Reform (110th-115th)","value":5777}]},{"label":"Rules (93rd-116th)","value":"hsru00","children":[{"label":"Rules (93rd-116th)","value":6085}]},{"label":"Science, Space, and Technology (112th-116th)","value":"hssy00","children":[{"label":"Science, Space, and Technology (112th-116th)","value":6152}]},{"label":"Small Business (93rd, 94th-116th)","value":"hssm00","children":[{"label":"Small Business (93rd, 94th-116th)","value":6093}]},{"label":"Transportation and Infrastructure (104th-116th)","value":"hspw00","children":[{"label":"Transportation and Infrastructure (104th-116th)","value":6053}]},{"label":"Veterans' Affairs (93rd-116th)","value":"hsvr00","children":[{"label":"Veterans' Affairs (93rd-116th)","value":6212}]},{"label":"Ways and Means (93rd-116th)","value":"hswm00","children":[{"label":"Ways and Means (93rd-116th)","value":6225}]}],
#     senateMultiselectData: [{"label":"Aging (Special) (93rd-116th)","value":"spag00","children":[{"label":"Aging (Special) (93rd-116th)","value":6299}]},{"label":"Agriculture, Nutrition, and Forestry (95th-116th)","value":"ssaf00","children":[{"label":"Agriculture, Nutrition, and Forestry (95th-116th)","value":6311}]},{"label":"Appropriations (93rd-116th)","value":"ssap00","children":[{"label":"Appropriations (93rd-116th)","value":6346}]},{"label":"Armed Services (93rd-116th)","value":"ssas00","children":[{"label":"Armed Services (93rd-116th)","value":6389}]},{"label":"Banking, Housing, and Urban Affairs (93rd-116th)","value":"ssbk00","children":[{"label":"Banking, Housing, and Urban Affairs (93rd-116th)","value":6423}]},{"label":"Budget (93rd-116th)","value":"ssbu00","children":[{"label":"Budget (93rd-116th)","value":6454}]},{"label":"Commerce, Science, and Transportation (95th-116th)","value":"sscm00","children":[{"label":"Commerce, Science, and Transportation (95th-116th)","value":6455}]},{"label":"Energy and Natural Resources (95th-116th)","value":"sseg00","children":[{"label":"Energy and Natural Resources (95th-116th)","value":6500}]},{"label":"Environment and Public Works (95th-116th)","value":"ssev00","children":[{"label":"Environment and Public Works (95th-116th)","value":6531}]},{"label":"Ethics (Select) (95th-116th)","value":"slet00","children":[{"label":"Ethics (Select) (95th-116th)","value":6279}]},{"label":"Finance (93rd-116th)","value":"ssfi00","children":[{"label":"Finance (93rd-116th)","value":6576}]},{"label":"Foreign Relations (93rd-116th)","value":"ssfr00","children":[{"label":"Foreign Relations (93rd-116th)","value":6608}]},{"label":"Health, Education, Labor, and Pensions (106th-116th)","value":"sshr00","children":[{"label":"Health, Education, Labor, and Pensions (106th-116th)","value":6679}]},{"label":"Homeland Security and Governmental Affairs (109th-116th)","value":"ssga00","children":[{"label":"Homeland Security and Governmental Affairs (109th-116th)","value":6641}]},{"label":"Indian Affairs (103rd-116th)","value":"slia00","children":[{"label":"Indian Affairs (103rd-116th)","value":6283}]},{"label":"Intelligence (Select) (94th-116th)","value":"slin00","children":[{"label":"Intelligence (Select) (94th-116th)","value":6285}]},{"label":"Judiciary (93rd-116th)","value":"ssju00","children":[{"label":"Judiciary (93rd-116th)","value":6715}]},{"label":"Rules and Administration (93rd-116th)","value":"ssra00","children":[{"label":"Rules and Administration (93rd-116th)","value":6766}]},{"label":"Small Business and Entrepreneurship (107th-116th)","value":"sssb00","children":[{"label":"Small Business and Entrepreneurship (107th-116th)","value":6769}]},{"label":"Veterans' Affairs (93rd-116th)","value":"ssva00","children":[{"label":"Veterans' Affairs (93rd-116th)","value":6798}]}],
#     qs_expand: null});
# </script>
# </div>
# <div aria-labelledby="legislation-text-tab" class="quick-search-tabui-tab-panel" id="legislation-text">
# <form action="/quick-search/legislation-text" aria-labelledby="quick-search" class="quick-search" method="GET">
# <div class="quick-search-form-row-words-and-phrases">
# <div class="quick-search-form-row quick-search-form-row-buttons quick-search-form-row-buttons-top">
# <button class="button tertiary2 reset" type="button">Reset</button>
# </div>
# <label class="quick-search-label quick-search-words-and-phrases-label" for="legislation-text-wordsPhrases">Words &amp; Phrases</label>
# <textarea aria-label="Words and Phrases" class="expand80-2000 words-and-phrases" id="legislation-text-wordsPhrases" name="wordsPhrases" placeholder="Examples: trade sanctions reform, small modular reactor" row="1"></textarea>
# </div>
# <div class="quick-search-form-row quick-search-form-row-after-words-and-phrases">
# <div class="quick-search-group">
# <div>
# <label class="quick-search-label-checkradio" for="legislation-text-booleanOperators"><input checked="checked" id="legislation-text-booleanOperators" name="booleanOperators" type="checkbox" value="on"/> Allow quotes and boolean operators</label>
# </div>
# <div>
# <label class="quick-search-label-checkradio" for="legislation-text-wordVariants"><input id="legislation-text-wordVariants" name="wordVariants" type="checkbox" value="on"/> Word Variants</label>
# <label class="quick-search-label-checkradio" for="legislation-text-caseSensitive"><input id="legislation-text-caseSensitive" name="caseSensitive" type="checkbox" value="on"/> Case Sensitive</label>
# </div>
# </div>
# </div>
# <div class="quick-search-column-wrapper">
# <div class="quick-search-two-column quick-search-two-column-left quick-search-form-left">
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="legislation-text-congresses">Congress</label>
# <select class="congresses" id="legislation-text-congresses" multiple="" name="congresses[]" size="5">
# <option value="all">All Congresses 101-116 (1989-2020)</option><option selected="selected" value="116">116 (2019-2020)</option><option selected="selected" value="115">115 (2017-2018)</option><option value="114">114 (2015-2016)</option><option value="113">113 (2013-2014)</option><option value="112">112 (2011-2012)</option><option value="111">111 (2009-2010)</option><option value="110">110 (2007-2008)</option><option value="109">109 (2005-2006)</option><option value="108">108 (2003-2004)</option><option value="107">107 (2001-2002)</option><option value="106">106 (1999-2000)</option><option value="105">105 (1997-1998)</option><option value="104">104 (1995-1996)</option><option value="103">103 (1993-1994)</option><option value="102">102 (1991-1992)</option><option value="101">101 (1989-1990)</option> </select>
# </div>
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="legislation-text-legislationNumbers">Legislation Numbers</label>
# <input id="legislation-text-legislationNumbers" name="legislationNumbers" placeholder="Examples: hr5, h.r.5, sjres 8, s2" type="text" value=""/>
# </div>
# <div class="quick-search-form-row">
# <fieldset class="quick-search-fieldset">
# <legend class="quick-search-legend">Chamber of Origin</legend>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="legislation-text-chamberOfOriginHouse"><input checked="checked" id="legislation-text-chamberOfOriginHouse" name="chamberOfOriginHouse" type="checkbox" value="on"/> House</label></div>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="legislation-text-chamberOfOriginSenate"><input checked="checked" id="legislation-text-chamberOfOriginSenate" name="chamberOfOriginSenate" type="checkbox" value="on"/> Senate</label></div>
# </fieldset>
# </div>
# </div>
# <div class="quick-search-two-column quick-search-two-column-right quick-search-form-right">
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="legislation-text-versions">Bill Text Versions</label>
# <select id="legislation-text-versions" multiple="" name="billTextVersionTypes[]" size="16">
# <option selected="selected" value="all">Any Version of Legislation</option><option value="AS">AS - Amendment Ordered to be Printed</option><option value="ATH">ATH - Agreed to House</option><option value="ATS">ATS - Agreed to Senate</option><option value="CDH">CDH - Committee Discharged House</option><option value="CDS">CDS - Committee Discharged Senate</option><option value="CPH">CPH - Considered and Passed House</option><option value="CPS">CPS - Considered and Passed Senate</option><option value="EAH">EAH - Engrossed Amendment House</option><option value="EAS">EAS - Engrossed Amendment Senate</option><option value="EH">EH - Engrossed in House</option><option value="ENR">ENR - Enrolled</option><option value="ES">ES - Engrossed in Senate</option><option value="FPH">FPH - Failed Passage House</option><option value="HDS">HDS - Held at Desk Senate</option><option value="IH">IH - Introduced in House</option><option value="IPS">IPS - Indefinitely Postponed Senate</option><option value="IS">IS - Introduced in Senate</option><option value="LTH">LTH - Laid on Table in House</option><option value="LTS">LTS - Laid on Table in Senate</option><option value="PAP">PAP - Printed as Passed</option><option value="PCS">PCS - Placed on Calendar Senate</option><option value="PCS2">PCS2 - Placed on Calendar Senate</option><option value="PP">PP - Public Print</option><option value="RCH">RCH - Reference Change House</option><option value="RCS">RCS - Reference Change Senate</option><option value="RDS">RDS - Received in Senate</option><option value="RFH">RFH - Referred in House</option><option value="RFS">RFS - Referred in Senate</option><option value="RH">RH - Reported in House</option><option value="RIH">RIH - Referral Instructions House</option><option value="RS">RS - Reported to Senate</option><option value="RTH">RTH - Referred to Committee House</option><option value="RTS">RTS - Referred to Committee Senate</option> </select>
# </div>
# </div>
# </div>
# <div class="quick-search-form-row quick-search-form-row-buttons">
# <button class="button primary2 submit" type="button">Search</button>
# <button class="button tertiary2 reset" type="button">Reset</button>
# </div>
# <div class="quick-search-form-row quick-search-form-row-intro">
# <a href="/legislation/about-legislation-text" target="_blank">About Legislation Text</a> | <a href="/browse#browse_legislation">Browse Legislation by Number</a> </div>
# </form>
# <script>
# $('#legislation-text form.quick-search').congress_QuickSearchLegislationText({
#     defaults: {"congresses":[116,115],"legislationNumbers":"","wordsPhrases":"","wordVariants":"","caseSensitive":"","billTextVersionTypes":["all"],"chamberOfOriginHouse":"on","chamberOfOriginSenate":"on","startAt":1,"pageSize":500,"pageSort":"billNumber:desc","booleanOperators":"on"},
#     resetFormUrl: '/quick-search/reset-form-selections',
#     qs_expand: null});
# </script>
# </div>
# <div aria-labelledby="committee-reports-tab" class="quick-search-tabui-tab-panel" id="committee-reports">
# <form action="/quick-search/committee-reports" aria-labelledby="quick-search" class="quick-search">
# <div class="quick-search-form-row-words-and-phrases">
# <div class="quick-search-form-row quick-search-form-row-buttons quick-search-form-row-buttons-top">
# <button class="button tertiary2 reset" type="button">Reset</button>
# </div>
# <label class="quick-search-label quick-search-words-and-phrases-label" for="committee-reports-wordsPhrases">Words &amp; Phrases</label>
# <textarea aria-label="Words and Phrases" class="expand80-2000 words-and-phrases" id="committee-reports-wordsPhrases" name="wordsPhrases" placeholder='Examples: baseball, "standing rules"' row="1"></textarea>
# </div>
# <div class="quick-search-form-row quick-search-form-row-after-words-and-phrases">
# <div class="quick-search-group">
# <div>
# <label class="quick-search-label-checkradio" for="committee-reports-wordVariants"><input checked="checked" id="committee-reports-wordVariants" name="wordVariants" type="checkbox" value="on"/> Word Variants</label>
# <label class="quick-search-label-checkradio" for="committee-reports-caseSensitive"><input id="committee-reports-caseSensitive" name="caseSensitive" type="checkbox" value="on"/> Case Sensitive</label>
# </div>
# <div>
# <label class="quick-search-label-checkradio" for="committee-reports-fullText"><input checked="checked" id="committee-reports-fullText" name="searchIn" type="radio" value="fullText"/> Full Text</label>
# <label class="quick-search-label-checkradio" for="committee-reports-titlesOnly"><input id="committee-reports-titlesOnly" name="searchIn" type="radio" value="titlesOnly"/> Titles Only</label>
# </div>
# </div>
# </div>
# <div class="quick-search-column-wrapper">
# <div class="quick-search-two-column">
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="committee-reports-congresses">Congress</label>
# <select id="committee-reports-congresses" multiple="" name="congresses[]" size="5">
# <option value="all">All Congresses 104-116 (1995-2020)</option><option selected="selected" value="116">116 (2019-2020)</option><option selected="selected" value="115">115 (2017-2018)</option><option value="114">114 (2015-2016)</option><option value="113">113 (2013-2014)</option><option value="112">112 (2011-2012)</option><option value="111">111 (2009-2010)</option><option value="110">110 (2007-2008)</option><option value="109">109 (2005-2006)</option><option value="108">108 (2003-2004)</option><option value="107">107 (2001-2002)</option><option value="106">106 (1999-2000)</option><option value="105">105 (1997-1998)</option><option value="104">104 (1995-1996)</option> </select>
# </div>
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="committee-reports-reportNumbers">Report Numbers</label>
# <input id="committee-reports-reportNumbers" name="reportNumbers" placeholder="Examples: 5, 20" type="text" value=""/>
# </div>
# <div class="quick-search-form-row checkradio-only">
# <fieldset class="quick-search-fieldset">
# <legend class="quick-search-legend">Report Types</legend>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="committee-reports-executiveRpt"><input checked="checked" id="committee-reports-executiveRpt" name="executiveRpt" type="checkbox" value="on"/> Executive</label></div>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="committee-reports-houseRpt"><input checked="checked" id="committee-reports-houseRpt" name="houseRpt" type="checkbox" value="on"/> House</label></div>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="committee-reports-senateRpt"><input checked="checked" id="committee-reports-senateRpt" name="senateRpt" type="checkbox" value="on"/> Senate</label></div>
# </fieldset>
# </div>
# <div class="quick-search-form-row checkradio-only">
# <label class="quick-search-label quick-search-block">Conference Reports</label>
# <div class="quick-search-inline-block"><label class="quick-search-label-checkradio" for="committee-reports-conferenceReports"><input id="committee-reports-conferenceReports" name="conferenceReports" type="checkbox" value="on"/> Conference Reports Only</label></div>
# </div>
# </div>
# <div class="quick-search-two-column quick-search-two-column-right quick-search-form-right active">
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="committee-reports-legislationNumbers">Legislation and Law Numbers</label>
# <input id="committee-reports-legislationNumbers" name="legislationNumbers" placeholder="Examples: hres583, H.Res.583, s782, s. 782" type="text" value=""/>
# </div>
# <div class="quick-search-form-row">
# <label class="quick-search-label" for="committee-reports-houseCommittees">Committees</label>
# ...
#             'collapseOverview': false,
#             'searchResultViewType': 'expanded'
#         });
#     }
# </script>
# <script>$(function() {function applyHighlights() {$("#content").mark("student", {"element":"mark","className":"searchterm-highlight","separateWordSearch":true,"wordBoundary":true,"exclude":[".breadcrumbs",".breadcrumbs a",".tabs_links a","h2.primary","h2.primary > span","small.right",".tertiary_section > h3",".search-lozenge","[id^=facetItem]","[id^=facetbox] > h2",".facet-lozenge",".overview_label .label_text","h1 > span","[id^=tab] > a","[target=_blank]","textarea","#introText p",".facetbox h1 a, .facetbox h2 a","button.quick-adv-search-toggle span","span.advSearchHelpSection","h2.no-results-error ~ ul li","div.tertiary_section ul li","h2.primary small a",".locshare-toolbar span a",".result-item strong",".overview table tbody tr th",".cdg-summary-wrapper-header",".counter","#display-message","#display-message strong",".expanded",".refine-title",".facetbox a",".facetbox h3",".overview_label a",".main-wrapper p a","table thead th",".overview td a",".tertiary li a",".currentVersion",".currentVersion span","#titles_main h4","#titles_main h3",".cdg-summary-wrapper p",".cdg-summary-wrapper li",".cdg-summary-wrapper a",".cdg-summary-wrapper .info",".cdg-summary-wrapper label","#summarySelector","#summarySelector p","#summarySelector a",".visualIndicator",".rsbtn_text span",".result-tracker li",".bill_progress li",".back-to-this-bill a",".overview_billprogress h3",".result-item a",".saved-search-toolbar a",".basic-search-tune span",".basic-search-tune label",".basic-search-tune button",".basic-search-tune button",".basic-search-tune-number span",".basic-search-tune-number strong",".all-info-content h2",".all-info-content h3","#subjects-content .search-column-nav p",".all-info-content .main-wrapper p","p > input[type=\"checkbox\"] ~ a","p > input[type=\"checkbox\"] ~ a ~ span",".no-highlighting *"]});$("#content").mark("debt", {"element":"mark","className":"searchterm-highlight","separateWordSearch":true,"wordBoundary":true,"exclude":[".breadcrumbs",".breadcrumbs a",".tabs_links a","h2.primary","h2.primary > span","small.right",".tertiary_section > h3",".search-lozenge","[id^=facetItem]","[id^=facetbox] > h2",".facet-lozenge",".overview_label .label_text","h1 > span","[id^=tab] > a","[target=_blank]","textarea","#introText p",".facetbox h1 a, .facetbox h2 a","button.quick-adv-search-toggle span","span.advSearchHelpSection","h2.no-results-error ~ ul li","div.tertiary_section ul li","h2.primary small a",".locshare-toolbar span a",".result-item strong",".overview table tbody tr th",".cdg-summary-wrapper-header",".counter","#display-message","#display-message strong",".expanded",".refine-title",".facetbox a",".facetbox h3",".overview_label a",".main-wrapper p a","table thead th",".overview td a",".tertiary li a",".currentVersion",".currentVersion span","#titles_main h4","#titles_main h3",".cdg-summary-wrapper p",".cdg-summary-wrapper li",".cdg-summary-wrapper a",".cdg-summary-wrapper .info",".cdg-summary-wrapper label","#summarySelector","#summarySelector p","#summarySelector a",".visualIndicator",".rsbtn_text span",".result-tracker li",".bill_progress li",".back-to-this-bill a",".overview_billprogress h3",".result-item a",".saved-search-toolbar a",".basic-search-tune span",".basic-search-tune label",".basic-search-tune button",".basic-search-tune button",".basic-search-tune-number span",".basic-search-tune-number strong",".all-info-content h2",".all-info-content h3","#subjects-content .search-column-nav p",".all-info-content .main-wrapper p","p > input[type=\"checkbox\"] ~ a","p > input[type=\"checkbox\"] ~ a ~ span",".no-highlighting *"]});$("#content").mark("loan", {"element":"mark","className":"searchterm-highlight","separateWordSearch":true,"wordBoundary":true,"exclude":[".breadcrumbs",".breadcrumbs a",".tabs_links a","h2.primary","h2.primary > span","small.right",".tertiary_section > h3",".search-lozenge","[id^=facetItem]","[id^=facetbox] > h2",".facet-lozenge",".overview_label .label_text","h1 > span","[id^=tab] > a","[target=_bla ...
# </div>
# <footer role="contentinfo">
# <script>
#         /* header mobile menu - header */
#         $('.menu_mobile a.menu_link').click(function () {
#             $('.menu_mobile ul.menu_list').slideToggle('fast');
#         });
#     </script>
# <div class="foot_logo">
# <h1><a class="logo_congress" href="https://www.congress.gov"><span><img alt="Congress.gov" src="https://www.congress.gov/img/svg/congress-gov-logo-no-color.svg" width="212"/></span></a></h1>
# </div>
# <div class="foot_group">
# <div>
# <h2>Site Content</h2>
# <ul>
# <li><a href="https://www.congress.gov/legislation?q=%7B%22congress%22%3A116%7D">Legislation</a></li>
# <li><a href="https://www.congress.gov/congressional-record">Congressional Record</a></li>
# <li><a href="https://www.congress.gov/congressional-record/congressional-record-index">Congressional Record Index</a></li>
# <li><a href="https://www.congress.gov/members?q=%7B%22congress%22%3A116%7D">Members</a></li>
# <li><a href="https://www.congress.gov/committees">Committees</a></li>
# <li><a href="https://www.congress.gov/congressional-reports">Committee Reports</a></li>
# <li><a href="https://www.congress.gov/nominations">Nominations</a></li>
# <li><a href="https://www.congress.gov/treaties">Treaty Documents</a></li>
# <li><a href="/house-communications">House Communications</a></li>
# <li><a href="/senate-communications">Senate Communications</a></li>
# <li><a href="https://www.congress.gov/legislative-process">Legislative Process</a></li>
# <li><a href="https://www.congress.gov/about">About Congress.gov</a></li>
# </ul>
# </div>
# <div>
# <h2>Help</h2>
# <ul>
# <li><a href="https://www.congress.gov/help">Help</a> | <a href="https://www.congress.gov/survey">Feedback</a> | <a href="https://www.congress.gov/contact-us">Contact Us</a></li>
# <li><a href="https://www.congress.gov/help/legislative-glossary">Glossary</a></li>
# <li><a href="https://www.congress.gov/help/search-tools-overview">Search Tools</a></li>
# <li><a href="http://www.loc.gov/rr/askalib/ask-law.html" target="_blank">Ask a Law Librarian</a></li>
# <li><a href="http://www.loc.gov/law/opportunities/seminar-orient.php" target="_blank">Webinars</a></li>
# </ul>
# <h2>Ways to Connect</h2>
# <ul>
# <li><a href="https://twitter.com/congressdotgov" target="_blank"><i class="icon twitter"></i>Twitter</a></li>
# <li><a href="https://www.youtube.com/playlist?list=PLpAGnumt6iV6j07liSyksxaQe_KmPbeow" target="_blank"><i class="icon youtube"></i>YouTube</a></li>
# <li><a href="https://www.congress.gov/video"><i class="fa fa-video-camera"></i> Video</a></li>
# <li><a href="https://www.congress.gov/rss">RSS &amp; Email Alerts</a></li>
# <li><a href="http://blogs.loc.gov/law/" target="_blank">Blog – In Custodia Legis: Law Librarians of Congress</a></li>
# </ul>
# </div>
# <div>
# <h2>Resources</h2>
# <ul>
# <li><a href="/resources/" target="_blank">Congress.gov Resources</a></li>
# <li> <a href="https://crsreports.congress.gov/" target="_blank">CRS Reports</a>
# </li>
# <li><a href="http://uscode.house.gov/" target="_blank">U.S. Code</a></li>
# <li><a href="https://www.govinfo.gov/" target="_blank">GPO govinfo</a></li>
# <li><a href="http://www.loc.gov/law/" target="_blank">Law Library of Congress</a></li>
# <li><a href="http://www.loc.gov/law/help/guide.php" target="_blank">Guide to Law Online</a></li>
# <li><a href="http://www.loc.gov/law/find/educational-resources/">Teacher Lesson Plans</a></li>
# <li><a href="https://www.congress.gov/state-legislature-websites" target="_blank">State Legislature Websites</a></li>
# <li><a href="https://www.congress.gov/about/data">Bill Status Bulk Data</a></li>
# <li><a href="https://www.congress.gov/roll-call-votes">Roll Call Votes</a></li>
# <li><a href="/constitution-annotated/" target="_blank">Constitution Annotated</a></li>
# </ul>
# </div>
# <div>
# <h2>House Links</h2>
# <ul>
# <li><a href="http://www.house.gov/" target="_blank">House.gov</a></li>
# <li><a href="http://clerk.house.gov/floorsummary/floor.aspx" target="_blank">Floor Activities</a></li>
# <li><a href="http://www.house.gov/representatives/" target="_blank">Representatives</a></li>
# <li><a href="http://www.house.gov/committees/" target="_blank">Committees</a></li>
# <li><a href="https://www.congress.gov/committees/video">Hearings (Video)</a></li>
# <li><a href="http://docs.house.gov/floor/" target="_blank">Bills to Be Considered</a></li>
# <li><a href="http://clerk.house.gov/member_info/leadership.aspx" target="_blank">Leadership</a></li>
# <li><a href="http://history.house.gov/" target="_blank">History, Art &amp; Archives</a></li>
# <li><a href="/resources/display/content/House+of+Representatives" target="_blank">More House Resources</a></li>
# </ul>
# </div>
# <div class="last">
# <h2>Senate Links</h2>
# <ul>
# <li><a href="http://www.senate.gov/" target="_blank">Senate.gov</a></li>
# <li><a href="http://www.senate.gov/legislative/LIS/floor_activity/floor_activity.htm" target="_blank">On the Senate Floor</a></li>
# <li><a href="http://www.senate.gov/general/contact_information/senators_cfm.cfm" target="_blank">Senators</a></li>
# <li><a href="http://www.senate.gov/pagelayout/committees/d_three_sections_with_teasers/committees_home.htm" target="_blank">Committees</a></li>
# <li><a href="http://www.senate.gov/pagelayout/committees/b_three_sections_with_teasers/committee_hearings.htm" target="_blank">Hearings (Schedule)</a></li>
# <li><a href="http://www.senate.gov/pagelayout/senators/a_three_sections_with_teasers/leadership.htm" target="_blank">Leadership</a></li>
# <li><a href="http://www.senate.gov/pagelayout/reference/g_three_sections_with_teasers/reference_home.htm" target="_blank">History, Art &amp; Statistics</a></li>
# <li><a href="/resources/display/content/Senate" target="_blank">More Senate Resources</a></li>
# </ul>
# </div>
# </div>
# <div class="foot_tertiary">
# <ul class="foot_links">
# <li class="first"><a href="https://www.loc.gov/legal">Legal</a></li>
# <li><a href="https://www.congress.gov/accessibility">Accessibility</a></li>
# <li><a href="https://www.congress.gov/help">Help</a></li>
# <li><a href="https://www.congress.gov/contact-us">Contact Us</a></li>
# <li><a href="http://www.loc.gov/global/disclaim.html" target="_blank">External Link Disclaimer</a></li>
# <li><a href="http://www.usa.gov/" target="_blank">USA.gov</a></li>
# </ul>
# <ul class="foot_partners">
# <li><a class="logo-loc" href="http://www.loc.gov/"><span><img alt="Library of Congress" src="https://www.congress.gov/img/svg/loc-gov-logo.svg" width="114"/></span></a></li>
# <li><a class="logo-copyright" href="http://www.copyright.gov/"><span><img alt="Copyright.gov" src="https://www.congress.gov/img/svg/copyright-logo.svg" width="167"/></span></a></li>
# </ul>
# </div>
# <div class="top-link">
# <a href="#" id="sticky-back-to-top" style="display: none;"><i></i><span>Back to top</span></a>
# </div>
# <script type="text/javascript">
#     $(function () {
#         var scroll_timer,
#             displayed = false,
#             $message = $('.top-link a').hide(),
#             $window = $(window),
#             top = $(document.body).children(0).position().top;
#
#         $("#sticky-back-to-top").click(function(event){
#             $window.scrollTop(0);
#             event.preventDefault();
#             return false;
#         });
#
#         $window.scroll(function () {
#             window.clearTimeout(scroll_timer);
#             scroll_timer = window.setTimeout(function () {
#                 if($window.scrollTop() <= top){
#                     displayed = false;
#                     $message.fadeOut(800);
#                 }else if(displayed == false){
#                     displayed = true;
#                     $message.stop(true, true).show().click(function () { $message.fadeOut(800); });
#                 }
#             }, 100);
#         });
#     });
#     </script>
# </footer><!-- end footer -->
# <script src="/js/cache/f8733cc80973f5c6033f9e1736e4eaf4.js" type="text/javascript"></script>
# </div><div class="ui-datepicker ui-widget ui-widget-content ui-helper-clearfix ui-corner-all" id="ui-datepicker-div"></div>
# <div class="actionLoaderWrapper" style="display:none">
# <div class="actionLoader">
# <i class="fa fa-circle-o-notch fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span>
# </div>
# </div>
# <script>
#     $(document).ready(function(){
#         var h = window.location.hash,
#             scrollTo = 0;
#
#         if (h) {
#             if ($(h).offset() !== undefined) {
#                 scrollTo = $(h).offset().top;
#             }
#         }
#
#         if (scrollTo > 0) {
#             $('html, body').stop().animate({ scrollTop : scrollTo + "px"}, 0);
#         }
#
#         $('body').congress_LAC({ checkUrl: '/lac/check' });
#     });
#     </script>
# <div aria-live="assertive" aria-relevant="additions" class="ui-helper-hidden-accessible" role="log"></div><div aria-describedby="ui-id-1" aria-labelledby="ui-id-2" class="ui-dialog ui-corner-all ui-widget ui-widget-content ui-front sign-in-box-wrapper ui-resizable" role="dialog" style="display: none; position: absolute;" tabindex="-1"><div class="ui-dialog-titlebar ui-corner-all ui-widget-header ui-helper-clearfix"><span class="ui-dialog-title" id="ui-id-2">Sign In</span><button class="ui-button ui-corner-all ui-widget ui-button-icon-only ui-dialog-titlebar-close" title="Close" type="button"><span class="ui-button-icon ui-icon ui-icon-closethick"></span><span class="ui-button-icon-space"> </span>Close</button></div><div class="sign-in-box ui-dialog-content ui-widget-content" id="ui-id-1">
# <div class="login form-account" id="login">
# <a class="sign-in-close-link" href="#"><span>Close</span></a>
# <form action="/account/signin" method="post">
# <div class="login-top">
# <h2>Sign In</h2>
# <div class="error-box" id="loginerrorbox"></div>
# <p>
# <label for="loginemailaddress">Email</label>
# <input id="loginemailaddress" name="emailAddress" type="email" value=""/>
# </p>
# <p>
# <label for="loginpassword">Password</label>
# <input id="loginpassword" name="password" type="password"/>
# </p>
# <p class="checkbox">
# <input id="remembermeh" name="rememberme" type="checkbox" value="on"/> <label for="remembermeh">Remember Me</label>
# </p>
# </div>
# <div class="login-bottom">
# <button class="button primary" id="loginsubmit" type="submit" value="submit">Sign in</button>
# <div class="login-help-links">
# <a href="/account/password-reset-request">Forgot password</a>?
#                     <a href="/account/register">Create an account</a>
# </div>
# </div>
# </form>
# </div>
# </div><div class="ui-resizable-handle ui-resizable-n" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-e" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-s" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-w" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-se ui-icon ui-icon-gripsmall-diagonal-se" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-sw" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-ne" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-nw" style="z-index: 90;"></div></div></body></html>

# %%
#result-heading
bill_heading = soup.find('span', class_= 'result-heading').text
bill_heading
# Out:
# 'S.2169 — 115th Congress (2017-2018)'

# %%
bill_title = soup.find('span', class_= 'result-title').text
bill_title
# Out:
# 'Student Right to Know Before You Go Act of 2017'

# %%
bill_details = soup.find('span', class_ = 'result-item')
bill_details
#print(bill_details.prettify())
# Out:
# <span class="result-item">
# <strong>Sponsor:</strong> <a href="/member/ron-wyden/W000779?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Wyden, Ron [D-OR]</a> (Introduced 11/29/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2169/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=1&amp;overview=closed#tabs">3</a>)        </span>

# %%
# name = bill_details('a')[0].text
# name

# %%
# last_name = name.split()[1]
# last_name

# %%
# first_name = name.split()[2]
# first_name

# %%
# party = name.split()[3][1]
# party

# %%
# state = name.split()[3][3:5]
# state

# %%
# cosponsors = bill_details('a')[1].text
# cosponsors

# %%
# date_introduced = str(bill_details.text)
# date_introduced = date_introduced[date_introduced.find("(")+1:date_introduced.find(")")].split()[1]
# date_introduced

# %%
bills = soup.find_all('ol', class_ = 'basic-search-results-lists expanded-view')
bills = bills[0].find_all('li', class_ = 'expanded')
bills
# Out:
# [<li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      1.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2169?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=1">S.2169</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title"><mark class="searchterm-highlight" data-markjs="true">Student</mark> Right to Know Before You Go Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/ron-wyden/W000779?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Wyden, Ron [D-OR]</a> (Introduced 11/29/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2169/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=1&amp;overview=closed#tabs">3</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 11/29/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2169/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=1&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-11-29
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      2.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/888?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=2">S.888</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Understanding the True Cost of College Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/charles-grassley/G000386?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Grassley, Chuck [R-IA]</a> (Introduced 04/07/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/888/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=2&amp;overview=closed#tabs">9</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 04/07/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/888/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=2&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-04-07
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      3.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/799?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=3">S.799</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Dynamic Repayment Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/mark-warner/W000805?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Warner, Mark R. [D-VA]</a> (Introduced 03/30/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/799/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=3&amp;overview=closed#tabs">1</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Finance        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 03/30/2017 Read twice and referred to the Committee on Finance. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/799/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=3&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-03-30
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">LAW</span></div>
#      4.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2155?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=4">S.2155</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Economic Growth, Regulatory Relief, and Consumer Protection Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/michael-crapo/C000880?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Crapo, Mike [R-ID]</a> (Introduced 11/16/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2155/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=4&amp;overview=closed#tabs">26</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Banking, Housing, and Urban Affairs        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> 05/24/2018 Became Public Law No: 115-174. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2155/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=4&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Became Law</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first passed">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-12-18
#      [displayText] =&gt; Committee on Banking, Housing, and Urban Affairs. Reported by Senator Crapo with amendments. Without written report.
#      [externalActionCode] =&gt; 14000
#      [description] =&gt; Introduced
#  )
#  </div></li><li class="passed">Passed Senate<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-03-14
#      [displayText] =&gt; Passed/agreed to in Senate: Passed Senate with an amendment by Yea-Nay Vote. 67 - 31. Record Vote Number: 54.
#      [externalActionCode] =&gt; 17000
#      [description] =&gt; Passed Senate
#  )
#  </div></li><li class="passed">Passed House<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-05-22
#      [displayText] =&gt; Passed/agreed to in House: On passage Passed by the Yeas and Nays: 258 - 159 (Roll no. 216).(text: CR H4320-4340)
#      [externalActionCode] =&gt; 8000
#      [description] =&gt; Passed House
#  )
#  </div></li><li class="beforeselect passed">To President<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-05-24
#      [displayText] =&gt; Presented to President.
#      [externalActionCode] =&gt; 28000
#      [description] =&gt; To President
#  )
#  </div></li><li class="selected last">Became Law<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-05-24
#      [displayText] =&gt; Became Public Law No: 115-174.
#      [externalActionCode] =&gt; 36000
#      [description] =&gt; Became Law
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      5.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1384?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=5">S.1384</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Joint Consolidation <mark class="searchterm-highlight" data-markjs="true">Loan</mark> Separation Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/mark-warner/W000805?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Warner, Mark R. [D-VA]</a> (Introduced 06/20/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1384/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=5&amp;overview=closed#tabs">3</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 06/20/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1384/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=5&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-06-20
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      6.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2136?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=6">S.2136</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">PSLF Technical Corrections Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/sheldon-whitehouse/W000802?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Whitehouse, Sheldon [D-RI]</a> (Introduced 11/16/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2136/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=6&amp;overview=closed#tabs">4</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 11/16/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2136/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=6&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-11-16
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      7.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1628?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=7">S.1628</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Know Before You Owe Federal <mark class="searchterm-highlight" data-markjs="true">Student</mark> <mark class="searchterm-highlight" data-markjs="true">Loan</mark> Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/charles-grassley/G000386?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Grassley, Chuck [R-IA]</a> (Introduced 07/25/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1628/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=7&amp;overview=closed#tabs">3</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 07/25/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1628/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=7&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-07-25
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      8.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/3018?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=8">S.3018</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Degrees Not <mark class="searchterm-highlight" data-markjs="true">Debt</mark> Act of 2018</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/martin-heinrich/H001046?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Heinrich, Martin [D-NM]</a> (Introduced 06/06/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3018/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=8&amp;overview=closed#tabs">0</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Finance        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 06/06/2018 Read twice and referred to the Committee on Finance. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3018/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=8&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-06-06
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      9.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/3205?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=9">S.3205</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Know Before You Owe Private <mark class="searchterm-highlight" data-markjs="true">Education</mark> <mark class="searchterm-highlight" data-markjs="true">Loan</mark> Act of 2018</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/richard-durbin/D000563?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Durbin, Richard J. [D-IL]</a> (Introduced 07/12/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3205/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=9&amp;overview=closed#tabs">5</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 07/12/2018 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (text of measure as introduced: CR <a href="/congressional-record/volume-164/senate-section/page/S4952-4953">S4952-4953</a>) (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3205/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=9&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-07-12
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      10.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1619?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=10">S.1619</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">A bill to amend the Servicemembers Civil Relief Act to extend the interest rate limitation on <mark class="searchterm-highlight" data-markjs="true">debt</mark> entered into during military service to <mark class="searchterm-highlight" data-markjs="true">debt</mark> incurred during military service to consolidate or refinance <mark class="searchterm-highlight" data-markjs="true">student</mark> <mark class="searchterm-highlight" data-markjs="true">loan</mark>s incurred before military service.</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/richard-durbin/D000563?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Durbin, Richard J. [D-IL]</a> (Introduced 07/24/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1619/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=10&amp;overview=closed#tabs">4</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Veterans' Affairs        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 07/24/2017 Read twice and referred to the Committee on Veterans' Affairs. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1619/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=10&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-07-24
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      11.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/3584?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=11">S.3584</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Affordable <mark class="searchterm-highlight" data-markjs="true">Loan</mark>s for Any <mark class="searchterm-highlight" data-markjs="true">Student</mark> Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/jeff-merkley/M001176?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Merkley, Jeff [D-OR]</a> (Introduced 10/11/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3584/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=11&amp;overview=closed#tabs">9</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 10/11/2018 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3584/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=11&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-10-11
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      12.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2028?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=12">S.2028</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Protect <mark class="searchterm-highlight" data-markjs="true">Student</mark> Borrowers Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/john-reed/R000122?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Reed, Jack [D-RI]</a> (Introduced 10/26/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2028/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=12&amp;overview=closed#tabs">3</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 10/26/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (Sponsor introductory remarks on measure: CR <a href="/congressional-record/volume-163/senate-section/page/S6855">S6855</a>) (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2028/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=12&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-10-26
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      13.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1121?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=13">S.1121</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">College Transparency Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/orrin-hatch/H000338?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Hatch, Orrin G. [R-UT]</a> (Introduced 05/15/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1121/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=13&amp;overview=closed#tabs">15</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 05/15/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1121/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=13&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-05-15
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      14.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2356?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=14">S.2356</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Stronger Medical Workforce for Veterans Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/jon-tester/T000464?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Tester, Jon [D-MT]</a> (Introduced 01/30/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2356/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=14&amp;overview=closed#tabs">6</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Veterans' Affairs        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 01/30/2018 Read twice and referred to the Committee on Veterans' Affairs. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2356/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=14&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-01-30
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      15.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2224?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=15">S.2224</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Empowering <mark class="searchterm-highlight" data-markjs="true">Student</mark> Borrowers Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/joe-donnelly/D000607?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Donnelly, Joe [D-IN]</a> (Introduced 12/13/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2224/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=15&amp;overview=closed#tabs">2</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 12/13/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2224/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=15&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-12-13
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      16.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2228?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=16">S.2228</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Higher <mark class="searchterm-highlight" data-markjs="true">Education</mark> Reform and Opportunity Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/mike-lee/L000577?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Lee, Mike [R-UT]</a> (Introduced 12/13/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2228/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=16&amp;overview=closed#tabs">1</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 12/13/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2228/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=16&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-12-13
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      17.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2081?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=17">S.2081</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Empowering <mark class="searchterm-highlight" data-markjs="true">Student</mark>s Through Enhanced Financial Counseling Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/mark-warner/W000805?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Warner, Mark R. [D-VA]</a> (Introduced 11/06/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2081/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=17&amp;overview=closed#tabs">4</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 11/06/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2081/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=17&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-11-06
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      18.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/3771?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=18">S.3771</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Retirement Parity for <mark class="searchterm-highlight" data-markjs="true">Student</mark> <mark class="searchterm-highlight" data-markjs="true">Loan</mark>s Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/ron-wyden/W000779?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Wyden, Ron [D-OR]</a> (Introduced 12/18/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3771/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=18&amp;overview=closed#tabs">3</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Finance        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 12/18/2018 Read twice and referred to the Committee on Finance. (Sponsor introductory remarks on measure: CR <a href="/congressional-record/volume-164/senate-section/page/S7791">S7791</a>) (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3771/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=18&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-12-18
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      19.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/3595?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=19">S.3595</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title"><mark class="searchterm-highlight" data-markjs="true">Student</mark> <mark class="searchterm-highlight" data-markjs="true">Loan</mark> Repayment Acceleration Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/cory-gardner/G000562?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Gardner, Cory [R-CO]</a> (Introduced 10/11/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3595/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=19&amp;overview=closed#tabs">0</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Finance        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 10/11/2018 Read twice and referred to the Committee on Finance. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3595/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=19&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-10-11
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      20.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/850?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=20">S.850</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Foreign Medical School Accountability Fairness Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/richard-durbin/D000563?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Durbin, Richard J. [D-IL]</a> (Introduced 04/05/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/850/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=20&amp;overview=closed#tabs">1</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 04/05/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/850/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=20&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-04-05
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      21.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/3320?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=21">S.3320</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Protecting Seniors with <mark class="searchterm-highlight" data-markjs="true">Student</mark> <mark class="searchterm-highlight" data-markjs="true">Loan</mark>s Act of 2018</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/claire-mccaskill/M001170?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. McCaskill, Claire [D-MO]</a> (Introduced 08/01/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3320/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=21&amp;overview=closed#tabs">0</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Finance        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 08/01/2018 Read twice and referred to the Committee on Finance. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3320/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=21&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-08-01
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      22.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1162?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=22">S.1162</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Bank on <mark class="searchterm-highlight" data-markjs="true">Student</mark>s Emergency <mark class="searchterm-highlight" data-markjs="true">Loan</mark> Refinancing Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/elizabeth-warren/W000817?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Warren, Elizabeth [D-MA]</a> (Introduced 05/17/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1162/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=22&amp;overview=closed#tabs">39</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Finance        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 05/17/2017 Read twice and referred to the Committee on Finance. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1162/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=22&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-05-17
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      23.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2180?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=23">S.2180</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Christopher's Law</span>
#  <span class="result-item">
# ...
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/jeff-merkley/M001176?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Merkley, Jeff [D-OR]</a> (Introduced 07/10/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3189/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=62&amp;overview=closed#tabs">1</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Finance        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 07/10/2018 Read twice and referred to the Committee on Finance. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3189/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=62&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-07-10
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      63.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1521?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=63">S.1521</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title"><mark class="searchterm-highlight" data-markjs="true">Student</mark> <mark class="searchterm-highlight" data-markjs="true">Loan</mark> Relief Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/clarence-nelson/N000032?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Nelson, Bill [D-FL]</a> (Introduced 07/10/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1521/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=63&amp;overview=closed#tabs">0</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 07/10/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1521/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=63&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-07-10
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      64.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/3371?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=64">S.3371</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Protecting <mark class="searchterm-highlight" data-markjs="true">Student</mark>s from Worthless Degrees Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/jeff-merkley/M001176?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Merkley, Jeff [D-OR]</a> (Introduced 08/23/2018) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3371/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=64&amp;overview=closed#tabs">1</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 08/23/2018 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/3371/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=64&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-08-23
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      65.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1449?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=65">S.1449</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Serving our Rural Veterans Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/dan-sullivan/S001198?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Sullivan, Dan  [R-AK]</a> (Introduced 06/27/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1449/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=65&amp;overview=closed#tabs">1</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Veterans' Affairs        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 06/27/2017 Read twice and referred to the Committee on Veterans' Affairs. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1449/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=65&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-06-27
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      66.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/968?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=66">S.968</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Veterans Access to Care Act</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/amy-klobuchar/K000367?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Klobuchar, Amy [D-MN]</a> (Introduced 04/27/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/968/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=66&amp;overview=closed#tabs">1</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 04/27/2017 Read twice and referred to the Committee on Health, <mark class="searchterm-highlight" data-markjs="true">Education</mark>, Labor, and Pensions. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/968/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=66&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-04-27
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      67.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/1603?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=67">S.1603</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Agriculture, Rural Development, Food and Drug Administration, and Related Agencies Appropriations Act, 2018</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/john-hoeven/H001061?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. Hoeven, John [R-ND]</a> (Introduced 07/20/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1603/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=67&amp;overview=closed#tabs">0</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Appropriations        </span>
#  <span class="result-item">
#  <strong>Committee Reports:</strong> <a href="/congressional-report/115th-congress/senate-report/131/1?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">S. Rept. 115-131</a> </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 07/20/2017 Placed on Senate Legislative Calendar under General Orders. Calendar No. 177. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/1603/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=67&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-07-20
#      [displayText] =&gt; Committee on Appropriations. Original measure reported to Senate by Senator Hoeven. With written report No. 115-131.
#      [externalActionCode] =&gt; 14000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      68.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2184?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=68">S.2184</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Veterans Community Care and Access Act of 2017</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/john-mccain/M000303?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. McCain, John [R-AZ]</a> (Introduced 12/01/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2184/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=68&amp;overview=closed#tabs">3</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Veterans' Affairs        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 12/01/2017 Read twice and referred to the Committee on Veterans' Affairs. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2184/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=68&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2017-12-01
#      [displayText] =&gt; Introduced in Senate
#      [externalActionCode] =&gt; 10000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>,
#  <li class="expanded" style="display: block;"> <div><span class="visualIndicator">BILL</span></div>
#      69.
#      <span class="result-heading"><a href="https://www.congress.gov/bill/115th-congress/senate-bill/2060?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=69">S.2060</a> — 115th Congress (2017-2018)</span>
#  <span class="result-title">Burma Human Rights and Freedom Act of 2018</span>
#  <span class="result-item">
#  <strong>Sponsor:</strong> <a href="/member/john-mccain/M000303?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D" target="_blank">Sen. McCain, John [R-AZ]</a> (Introduced 11/02/2017) <strong>Cosponsors:</strong> (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2060/cosponsors?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=69&amp;overview=closed#tabs">24</a>)        </span>
#  <span class="result-item">
#  <strong>Committees:</strong> Senate - Foreign Relations        </span>
#  <span class="result-item"><strong> Latest Action:            </strong> Senate - 02/12/2018 Placed on Senate Legislative Calendar under General Orders. Calendar No. 307. (<a href="https://www.congress.gov/bill/115th-congress/senate-bill/2060/all-actions?q=%7B%22search%22%3A%5B%22student+debt+loan+education%22%5D%7D&amp;s=1&amp;r=69&amp;overview=closed#tabs">All Actions</a>)        </span>
#  <span class="result-item result-tracker"><strong>
#              Tracker: </strong><p class="hide_fromsighted">This bill has the status Introduced</p><p class="hide_fromsighted">Here are the steps for Status of Legislation:</p><ol class="stat_leg"><li class="first selected last">Introduced<div class="sol-step-info" style="display:none">Array
#  (
#      [actionDate] =&gt; 2018-02-12
#      [displayText] =&gt; Committee on Foreign Relations. Reported by Senator Corker with an amendment in the nature of a substitute. Without written report.
#      [externalActionCode] =&gt; 14000
#      [description] =&gt; Introduced
#  )
#  </div></li></ol> </span>
#  </li>]

# %%
# for bill in bills:
#     bill_title = bill.find('span', class_= 'result-title').text
#     bill_number = bill('a')[0].text
#     senator_name = bill('a')
#     #date = str(bill.text)
#     #date = date[date.find("(")+1:date.find(")")].split()[1]
#     print(senator_name)

# %%
len(bills)
# Out:
# 69

# %%
items = bills[0].find_all('li', class_ = 'expanded')

# %%
bills[0]('a')[0].text
# Out:
# 'S.2169'

# %%
name = bills[0]('a')[1].text

# %%
last_name = name.split()[1]
last_name
# Out:
# 'Wyden,'

# %%
first_name = name.split()[2]
first_name
# Out:
# 'Ron'

# %%
party = name.split()[3][1]
party
# Out:
# 'D'

# %%
state = name.split()[3][3:5]
state
# Out:
# 'OR'

# %%
cosponsors = bills[0]('a')[2].text
# Out:
# '3'

# %%
bills[0]('span')[2].text
# Out:
# 'Student Right to Know Before You Go Act of 2017'

# %%
date_introduced = str(bills[0]('span')[3].text)
date_introduced = date_introduced[date_introduced.find("(")+1:date_introduced.find(")")].split()[1]
date_introduced
# Out:
# '11/29/2017'

# %%
for bill in bills:
    bill_num = bill('a')[0].text
    senator_details = bill('a')[1].text
    last_name = senator_details.split()[1]
    first_name = senator_details.split()[2]
    cosponsors = bill('a')[2].text
    bill_name = bill('span')[2].text
    date_introduced = str(bill('span')[3].text)
    date_introduced = date_introduced[date_introduced.find("(")+1:date_introduced.find(")")].split()[1]
    
    
    print('------------------')
    print(date_introduced)
    print(bill_num)
    print(bill_name)
    print(senator_details)
    print(last_name)
    print(first_name)
    print(cosponsors)
    print('------------------')
# Out:
# ------------------
# 11/29/2017
# S.2169
# Student Right to Know Before You Go Act of 2017
# Sen. Wyden, Ron [D-OR]
# Wyden,
# Ron
# 3
# ------------------
# ------------------
# 04/07/2017
# S.888
# Understanding the True Cost of College Act of 2017
# Sen. Grassley, Chuck [R-IA]
# Grassley,
# Chuck
# 9
# ------------------
# ------------------
# 03/30/2017
# S.799
# Dynamic Repayment Act of 2017
# Sen. Warner, Mark R. [D-VA]
# Warner,
# Mark
# 1
# ------------------
# ------------------
# 11/16/2017
# S.2155
# Economic Growth, Regulatory Relief, and Consumer Protection Act
# Sen. Crapo, Mike [R-ID]
# Crapo,
# Mike
# 26
# ------------------
# ------------------
# 06/20/2017
# S.1384
# Joint Consolidation Loan Separation Act
# Sen. Warner, Mark R. [D-VA]
# Warner,
# Mark
# 3
# ------------------
# ------------------
# 11/16/2017
# S.2136
# PSLF Technical Corrections Act
# Sen. Whitehouse, Sheldon [D-RI]
# Whitehouse,
# Sheldon
# 4
# ------------------
# ------------------
# 07/25/2017
# S.1628
# Know Before You Owe Federal Student Loan Act of 2017
# Sen. Grassley, Chuck [R-IA]
# Grassley,
# Chuck
# 3
# ------------------
# ------------------
# 06/06/2018
# S.3018
# Degrees Not Debt Act of 2018
# Sen. Heinrich, Martin [D-NM]
# Heinrich,
# Martin
# 0
# ------------------
# ------------------
# 07/12/2018
# S.3205
# Know Before You Owe Private Education Loan Act of 2018
# Sen. Durbin, Richard J. [D-IL]
# Durbin,
# Richard
# 5
# ------------------
# ------------------
# 07/24/2017
# S.1619
# A bill to amend the Servicemembers Civil Relief Act to extend the interest rate limitation on debt entered into during military service to debt incurred during military service to consolidate or refinance student loans incurred before military service.
# Sen. Durbin, Richard J. [D-IL]
# Durbin,
# Richard
# 4
# ------------------
# ------------------
# 10/11/2018
# S.3584
# Affordable Loans for Any Student Act
# Sen. Merkley, Jeff [D-OR]
# Merkley,
# Jeff
# 9
# ------------------
# ------------------
# 10/26/2017
# S.2028
# Protect Student Borrowers Act of 2017
# Sen. Reed, Jack [D-RI]
# Reed,
# Jack
# 3
# ------------------
# ------------------
# 05/15/2017
# S.1121
# College Transparency Act
# Sen. Hatch, Orrin G. [R-UT]
# Hatch,
# Orrin
# 15
# ------------------
# ------------------
# 01/30/2018
# S.2356
# Stronger Medical Workforce for Veterans Act
# Sen. Tester, Jon [D-MT]
# Tester,
# Jon
# 6
# ------------------
# ------------------
# 12/13/2017
# S.2224
# Empowering Student Borrowers Act
# Sen. Donnelly, Joe [D-IN]
# Donnelly,
# Joe
# 2
# ------------------
# ------------------
# 12/13/2017
# S.2228
# Higher Education Reform and Opportunity Act of 2017
# Sen. Lee, Mike [R-UT]
# Lee,
# Mike
# 1
# ------------------
# ------------------
# 11/06/2017
# S.2081
# Empowering Students Through Enhanced Financial Counseling Act
# Sen. Warner, Mark R. [D-VA]
# Warner,
# Mark
# 4
# ------------------
# ------------------
# 12/18/2018
# S.3771
# Retirement Parity for Student Loans Act
# Sen. Wyden, Ron [D-OR]
# Wyden,
# Ron
# 3
# ------------------
# ------------------
# 10/11/2018
# S.3595
# Student Loan Repayment Acceleration Act
# Sen. Gardner, Cory [R-CO]
# Gardner,
# Cory
# 0
# ------------------
# ------------------
# 04/05/2017
# S.850
# Foreign Medical School Accountability Fairness Act of 2017
# Sen. Durbin, Richard J. [D-IL]
# Durbin,
# Richard
# 1
# ------------------
# ------------------
# 08/01/2018
# S.3320
# Protecting Seniors with Student Loans Act of 2018
# Sen. McCaskill, Claire [D-MO]
# McCaskill,
# Claire
# 0
# ------------------
# ------------------
# 05/17/2017
# S.1162
# Bank on Students Emergency Loan Refinancing Act
# Sen. Warren, Elizabeth [D-MA]
# Warren,
# Elizabeth
# 39
# ------------------
# ------------------
# 11/30/2017
# S.2180
# Christopher's Law
# Sen. Menendez, Robert [D-NJ]
# Menendez,
# Robert
# 3
# ------------------
# ------------------
# 02/05/2018
# S.2370
# STRIVE Act
# Sen. Booker, Cory A. [D-NJ]
# Booker,
# Cory
# 3
# ------------------
# ------------------
# 01/17/2017
# S.171
# National Oceanic and Atmospheric Administration Commissioned Officer Corps Amendments and Hydrographic Services Improvement Act Reauthorization and Amendments Act of 2017
# Sen. Sullivan, Dan  [R-AK]
# Sullivan,
# Dan
# 6
# ------------------
# ------------------
# 03/22/2018
# S.2598
# Debt-Free College Act of 2018
# Sen. Schatz, Brian [D-HI]
# Schatz,
# Brian
# 9
# ------------------
# ------------------
# 09/28/2017
# S.Res.275
# A resolution congratulating Northeastern Illinois University on the sesquicentennial of the University.
# Sen. Duckworth, Tammy [D-IL]
# Duckworth,
# Tammy
# 1
# ------------------
# ------------------
# 05/24/2018
# S.2984
# Strengthening American Communities Act of 2018
# Sen. Cardin, Benjamin L. [D-MD]
# Cardin,
# Benjamin
# 0
# ------------------
# ------------------
# 02/01/2017
# S.268
# Investing in Student Success Act of 2017
# Sen. Young, Todd C. [R-IN]
# Young,
# Todd
# 2
# ------------------
# ------------------
# 10/11/2018
# S.3596
# Innovation Zone Act
# Sen. Young, Todd C. [R-IN]
# Young,
# Todd
# 3
# ------------------
# ------------------
# 05/04/2017
# S.1042
# Segal AmeriCorps Education Award Enhancement Act of 2017
# Sen. Bennet, Michael F. [D-CO]
# Bennet,
# Michael
# 12
# ------------------
# ------------------
# 03/13/2017
# S.615
# Higher Education Innovation Act
# Sen. Bennet, Michael F. [D-CO]
# Bennet,
# Michael
# 1
# ------------------
# ------------------
# 01/25/2018
# S.2342
# Innovation Zone Act
# Sen. Young, Todd C. [R-IN]
# Young,
# Todd
# 0
# ------------------
# ------------------
# 11/28/2017
# S.2165
# Puerto Rico and Virgin Islands Equitable Rebuild Act of 2017
# Sen. Sanders, Bernard [I-VT]
# Sanders,
# Bernard
# 7
# ------------------
# ------------------
# 07/13/2017
# S.1551
# Economic Freedom Zones Act of 2017
# Sen. Paul, Rand [R-KY]
# Paul,
# Rand
# 1
# ------------------
# ------------------
# 12/05/2017
# S.2193
# Caring for our Veterans Act of 2017
# Sen. Isakson, Johnny [R-GA]
# Isakson,
# Johnny
# 0
# ------------------
# ------------------
# 12/19/2017
# S.2248
# Veterans Benefits and Transition Act of 2018
# Sen. Tester, Jon [D-MT]
# Tester,
# Jon
# 2
# ------------------
# ------------------
# 05/22/2018
# S.2906
# VA MISSION Act of 2018
# Sen. Manchin, Joe, III [D-WV]
# Manchin,
# Joe,
# 23
# ------------------
# ------------------
# 12/19/2018
# S.3781
# Retirement Security and Savings Act of 2018
# Sen. Portman, Rob [R-OH]
# Portman,
# Rob
# 1
# ------------------
# ------------------
# 09/07/2017
# S.1771
# Departments of Labor, Health and Human Services, and Education, and Related Agencies Appropriations Act, 2018
# Sen. Blunt, Roy [R-MO]
# Blunt,
# Roy
# 0
# ------------------
# ------------------
# 06/28/2018
# S.3158
# Departments of Labor, Health and Human Services, and Education, and Related Agencies Appropriations Act, 2019
# Sen. Blunt, Roy [R-MO]
# Blunt,
# Roy
# 0
# ------------------
# ------------------
# 02/05/2018
# S.2372
# VA MISSION Act of 2018
# Sen. Isakson, Johnny [R-GA]
# Isakson,
# Johnny
# 10
# ------------------
# ------------------
# 01/03/2017
# S.18
# Fair Tax Act of 2017
# Sen. Moran, Jerry [R-KS]
# Moran,
# Jerry
# 4
# ------------------
# ------------------
# 06/14/2018
# S.3073
# Department of the Interior, Environment, and Related Agencies Appropriations Act, 2019
# Sen. Murkowski, Lisa [R-AK]
# Murkowski,
# Lisa
# 0
# ------------------
# ------------------
# 10/31/2017
# S.2043
# Security and Financial Empowerment Act of 2017
# Sen. Murray, Patty [D-WA]
# Murray,
# Patty
# 8
# ------------------
# ------------------
# 02/15/2017
# S.385
# Energy Savings and Industrial Competitiveness Act
# Sen. Portman, Rob [R-OH]
# Portman,
# Rob
# 11
# ------------------
# ------------------
# 11/27/2018
# S.3660
# Health Equity and Accountability Act of 2018
# Sen. Hirono, Mazie K. [D-HI]
# Hirono,
# Mazie
# 10
# ------------------
# ------------------
# 05/16/2017
# S.1129
# Coast Guard Authorization Act of 2017
# Sen. Sullivan, Dan  [R-AK]
# Sullivan,
# Dan
# 3
# ------------------
# ------------------
# 06/11/2018
# S.3042
# Agriculture Improvement Act of 2018
# Sen. Roberts, Pat [R-KS]
# Roberts,
# Pat
# 1
# ------------------
# ------------------
# 07/27/2017
# S.1655
# Transportation, Housing and Urban Development, and Related Agencies Appropriations Act, 2018
# Sen. Collins, Susan M. [R-ME]
# Collins,
# Susan
# 0
# ------------------
# ------------------
# 06/21/2018
# S.3107
# Financial Services and General Government Appropriations Act, 2019
# Sen. Lankford, James [R-OK]
# Lankford,
# James
# 0
# ------------------
# ------------------
# 06/07/2018
# S.3023
# Transportation, Housing and Urban Development, and Related Agencies Appropriations Act, 2019
# Sen. Collins, Susan M. [R-ME]
# Collins,
# Susan
# 0
# ------------------
# ------------------
# 06/11/2018
# S.3041
# Disaster Recovery Reform Act of 2018
# Sen. Johnson, Ron [R-WI]
# Johnson,
# Ron
# 2
# ------------------
# ------------------
# 09/07/2017
# S.1780
# Department of State, Foreign Operations, and Related Programs Appropriations Act, 2018
# Sen. Graham, Lindsey [R-SC]
# Graham,
# Lindsey
# 0
# ------------------
# ------------------
# 06/21/2018
# S.3108
# Department of State, Foreign Operations, and Related Programs Appropriations Act, 2019
# Sen. Graham, Lindsey [R-SC]
# Graham,
# Lindsey
# 0
# ------------------
# ------------------
# 06/28/2017
# S.1460
# Energy and Natural Resources Act of 2017
# Sen. Murkowski, Lisa [R-AK]
# Murkowski,
# Lisa
# 1
# ------------------
# ------------------
# 11/28/2017
# S.1
# An original bill to provide for reconciliation pursuant to title II of the concurrent resolution on the budget for fiscal year 2018.
# Sen. Enzi, Michael B. [R-WY]
# Enzi,
# Michael
# 0
# ------------------
# ------------------
# 07/27/2017
# S.1648
# Legislative Branch Appropriations Act, 2018
# Sen. Lankford, James [R-OK]
# Lankford,
# James
# 0
# ------------------
# ------------------
# 08/21/2018
# S.3357
# Anti-Corruption and Public Integrity Act
# Sen. Warren, Elizabeth [D-MA]
# Warren,
# Elizabeth
# 0
# ------------------
# ------------------
# 06/05/2018
# S.2987
# John S. McCain National Defense Authorization Act for Fiscal Year 2019
# Sen. Inhofe, James M. [R-OK]
# Inhofe,
# James
# 0
# ------------------
# ------------------
# 07/10/2017
# S.1519
# National Defense Authorization Act for Fiscal Year 2018
# Sen. McCain, John [R-AZ]
# McCain,
# John
# 0
# ------------------
# ------------------
# 07/10/2018
# S.3189
# Income-Based Repayment Debt Forgiveness Act
# Sen. Merkley, Jeff [D-OR]
# Merkley,
# Jeff
# 1
# ------------------
# ------------------
# 07/10/2017
# S.1521
# Student Loan Relief Act of 2017
# Sen. Nelson, Bill [D-FL]
# Nelson,
# Bill
# 0
# ------------------
# ------------------
# 08/23/2018
# S.3371
# Protecting Students from Worthless Degrees Act
# Sen. Merkley, Jeff [D-OR]
# Merkley,
# Jeff
# 1
# ------------------
# ------------------
# 06/27/2017
# S.1449
# Serving our Rural Veterans Act of 2017
# Sen. Sullivan, Dan  [R-AK]
# Sullivan,
# Dan
# 1
# ------------------
# ------------------
# 04/27/2017
# S.968
# Veterans Access to Care Act
# Sen. Klobuchar, Amy [D-MN]
# Klobuchar,
# Amy
# 1
# ------------------
# ------------------
# 07/20/2017
# S.1603
# Agriculture, Rural Development, Food and Drug Administration, and Related Agencies Appropriations Act, 2018
# Sen. Hoeven, John [R-ND]
# Hoeven,
# John
# 0
# ------------------
# ------------------
# 12/01/2017
# S.2184
# Veterans Community Care and Access Act of 2017
# Sen. McCain, John [R-AZ]
# McCain,
# John
# 3
# ------------------
# ------------------
# 11/02/2017
# S.2060
# Burma Human Rights and Freedom Act of 2018
# Sen. McCain, John [R-AZ]
# McCain,
# John
# 24
# ------------------
